# %% [markdown]
# # Rural Emergency Triage AI - Colab Training
#
# This notebook runs everything in Google Colab (FREE GPU + storage)

# %%
# Mount Google Drive (for storing models)
from google.colab import drive
drive.mount('/content/drive')

# %%
# Install dependencies
# !pip install -q transformers accelerate peft bitsandbytes
# !pip install -q pydicom nibabel opencv-python albumentations
# !pip install -q kaggle

# %%
# Setup Kaggle credentials
# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Download SMALL subset of data (only 5GB!)
# We'll use a subset strategy
# !kaggle datasets download -d nih-chest-xrays/sample-data  # Smaller sample
# !unzip -q sample-data.zip -d /content/data/

# %%
# Clone your repo
# !git clone https://github.com/YOUR_USERNAME/rural-emergency-triage-ai.git
# %cd rural-emergency-triage-ai

# %%
# Train model (Colab has free GPU!)
# !python src/models/medgemma/train.py --config configs/hemorrhage_detection.yaml

# %%
# Save trained model to Google Drive
# !cp -r data/models/hemorrhage_detection /content/drive/MyDrive/triage_models/
